# %%
import pandas as pd
import os

# %%
csv_file = "Finalcopy.csv"
data = pd.read_csv(csv_file, encoding = 'utf-8')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
type(data['Date'])
# Out:
# pandas.core.series.Series

# %%
#Change Date into format
data = data.replace('-', '', regex=True)

# %%
data
# Out:
#                                                      LUID      Date  \
# 0       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180412
# 1       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180412
# 2       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 3       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 4       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 5       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 6       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 7       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 8       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 9       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 10      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 11      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180419
# 12      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180419
# ...

# %%
#Write to changeddata.csv file
os.remove("changeddata.csv")
data.to_csv("changeddata.csv", sep=',', encoding='utf-8')

# %%
data
# Out:
#                                                      LUID      Date  \
# 0       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180412
# 1       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180412
# 2       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 3       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 4       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 5       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 6       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 7       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 8       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 9       76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 10      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180416
# 11      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180419
# 12      76a2a43120782abc7cfa51bcee3f7805169367409ec944...  20180419
# ...
